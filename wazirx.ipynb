# %%
import requests
import time
import pandas as pd

# %%
data = requests.get('https://api.wazirx.com/api/v2/tickers')

# %%
write=print(data.json())
write
# Out:
# {'btcinr': {'base_unit': 'btc', 'quote_unit': 'inr', 'low': '5380000.0', 'high': '5440000.0', 'last': '5437235.0', 'type': 'SPOT', 'open': '5382000', 'volume': '0.90959', 'sell': '5437235.0', 'buy': '5402484.0', 'at': 1715575996, 'name': 'BTC/INR'}, 'xrpinr': {'base_unit': 'xrp', 'quote_unit': 'inr', 'low': '43.6083', 'high': '45.1', 'last': '43.8999', 'type': 'SPOT', 'open': '45.1', 'volume': '113526.9', 'sell': '43.8999', 'buy': '43.7002', 'at': 1715575996, 'name': 'XRP/INR'}, 'ethinr': {'base_unit': 'eth', 'quote_unit': 'inr', 'low': '255500.0', 'high': '261999.8', 'last': '258207.0', 'type': 'SPOT', 'open': '259900.2', 'volume': '17.0896', 'sell': '258207.0', 'buy': '255626.7', 'at': 1715575996, 'name': 'ETH/INR'}, 'trxinr': {'base_unit': 'trx', 'quote_unit': 'inr', 'low': '11.1', 'high': '11.2596', 'last': '11.175', 'type': 'SPOT', 'open': '11.1441', 'volume': '339713.0', 'sell': '11.2595', 'buy': '11.175', 'at': 1715575996, 'name': 'TRX/INR'}, 'eosinr': {'base_unit': 'eos', 'quote_unit': 'inr', 'low': '92.0', 'high': '98.38', 'last': '93.0', 'type': 'SPOT', 'open': '92.5', 'volume': '96.16', 'sell': '97.98', 'buy': '92.11', 'at': 1715575996, 'name': 'EOS/INR'}, 'zilinr': {'base_unit': 'zil', 'quote_unit': 'inr', 'low': '2.75', 'high': '2.94', 'last': '2.88', 'type': 'SPOT', 'open': '2.94', 'volume': '31272.0', 'sell': '2.88', 'buy': '2.75', 'at': 1715575996, 'name': 'ZIL/INR'}, 'batinr': {'base_unit': 'bat', 'quote_unit': 'inr', 'low': '20.001', 'high': '22.1', 'last': '20.5', 'type': 'SPOT', 'open': '21.07', 'volume': '6939.37', 'sell': '21.15', 'buy': '20.001', 'at': 1715575996, 'name': 'BAT/INR'}, 'zrxinr': {'base_unit': 'zrx', 'quote_unit': 'inr', 'low': '38.76', 'high': '41.66', 'last': '39.22', 'type': 'SPOT', 'open': '41.66', 'volume': '9582.27', 'sell': '39.17', 'buy': '38.96', 'at': 1715575996, 'name': 'ZRX/INR'}, 'reqinr': {'base_unit': 'req', 'quote_unit': 'inr', 'low': '10.4', 'high': '11.274', 'last': '10.4', 'type': 'SPOT', 'open': '11.0085', 'volume': '1121.0', 'sell': '10.3672', 'buy': '10.2308', 'at': 1715575996, 'name': 'REQ/INR'}, 'nulsinr': {'base_unit': 'nuls', 'quote_unit': 'inr', 'low': '108.0', 'high': '108.0', 'last': '108.0', 'type': 'SPOT', 'open': 108.0, 'volume': '0.0', 'sell': '0.0', 'buy': '0.0', 'at': 1715575996, 'name': 'NULS/INR'}, 'icxinr': {'base_unit': 'icx', 'quote_unit': 'inr', 'low': '19.0', 'high': '20.799', 'last': '19.0', 'type': 'SPOT', 'open': '20.5', 'volume': '5403.3', 'sell': '20.55', 'buy': '19.01', 'at': 1715575996, 'name': 'ICX/INR'}, 'omginr': {'base_unit': 'omg', 'quote_unit': 'inr', 'low': '53.154', 'high': '59.498', 'last': '53.154', 'type': 'SPOT', 'open': '58.02', 'volume': '5281.65', 'sell': '54.176', 'buy': '53.154', 'at': 1715575996, 'name': 'OMG/INR'}, 'iostinr': {'base_unit': 'iost', 'quote_unit': 'inr', 'low': '0.74', 'high': '0.8', 'last': '0.75', 'type': 'SPOT', 'open': '0.78', 'volume': '846698.0', 'sell': '0.75', 'buy': '0.74', 'at': 1715575996, 'name': 'IOST/INR'}, 'dentinr': {'base_unit': 'dent', 'quote_unit': 'inr', 'low': '0.11', 'high': '0.114', 'last': '0.11', 'type': 'SPOT', 'open': '0.114', 'volume': '748539.0', 'sell': '0.111', 'buy': '0.11', 'at': 1715575996, 'name': 'DENT/INR'}, 'hotinr': {'base_unit': 'hot', 'quote_unit': 'inr', 'low': '0.187', 'high': '0.203', 'last': '0.188', 'type': 'SPOT', 'open': '0.201', 'volume': '1529507.0', 'sell': '0.19', 'buy': '0.188', 'at': 1715575996, 'name': 'HOT/INR'}, 'funinr': {'base_unit': 'fun', 'quote_unit': 'inr', 'low': '0.44', 'high': '0.46', 'last': '0.46', 'type': 'SPOT', 'open': '0.46', 'volume': '194332.0', 'sell': '0.46', 'buy': '0.45', 'at': 1715575996, 'name': 'FUN/INR'}, 'usdtinr': {'base_unit': 'usdt', 'quote_unit': 'inr', 'low': '88.42', 'high': '89.47', 'last': '88.96', 'type': 'SPOT', 'open': '88.54', 'volume': '367302.17', 'sell': '89.38', 'buy': '88.98', 'at': 1715575996, 'name': 'USDT/INR'}, 'wrxinr': {'base_unit': 'wrx', 'quote_unit': 'inr', 'low': '17.67', 'high': '18.6', 'last': '17.7' ...

# %%
pip install gspread-dataframe
# Out:
# Requirement already satisfied: gspread-dataframe in c:\users\se7en\anaconda3\lib\site-packages (3.3.1)
# Requirement already satisfied: gspread>=3.0.0 in c:\users\se7en\anaconda3\lib\site-packages (from gspread-dataframe) (6.1.0)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\se7en\anaconda3\lib\site-packages (from gspread-dataframe) (1.5.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\se7en\anaconda3\lib\site-packages (from gspread-dataframe) (1.16.0)
# Requirement already satisfied: google-auth>=1.12.0 in c:\users\se7en\anaconda3\lib\site-packages (from gspread>=3.0.0->gspread-dataframe) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in c:\users\se7en\anaconda3\lib\site-packages (from gspread>=3.0.0->gspread-dataframe) (1.2.0)
# Requirement already satisfied: StrEnum==0.4.15 in c:\users\se7en\anaconda3\lib\site-packages (from gspread>=3.0.0->gspread-dataframe) (0.4.15)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\se7en\anaconda3\lib\site-packages (from pandas>=0.24.0->gspread-dataframe) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\se7en\anaconda3\lib\site-packages (from pandas>=0.24.0->gspread-dataframe) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\se7en\anaconda3\lib\site-packages (from pandas>=0.24.0->gspread-dataframe) (1.24.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\se7en\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread>=3.0.0->gspread-dataframe) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\se7en\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread>=3.0.0->gspread-dataframe) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\se7en\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread>=3.0.0->gspread-dataframe) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\se7en\anaconda3\lib\site-packages (from google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (2.0.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\se7en\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread>=3.0.0->gspread-dataframe) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\se7en\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in c:\users\se7en\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\se7en\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\se7en\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\se7en\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\se7en\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
import gspread
import pandas as pd

# %%
cred_file="real-time-price-data-403bcaed58e5.json"
gc=gspread.service_account(cred_file)
gc

# %%
cp=gc.open("CryptoPrices")

# %%
wks = cp.worksheet("price")
wks
# Out:
# <Worksheet 'price' id:0>

# %%
cell_list= wks.range('A2:A23')
cell_value = [
    data.json()['btcinr']['name'],
    data.json()['iostinr']['name'],
    data.json()['xrpinr']['name'],
    data.json()['ethinr']['name'],
    data.json()['zilinr']['name'],
    data.json()['batinr']['name'],
    data.json()['reqinr']['name'],
    data.json()['nulsinr']['name'],
    data.json()['icxinr']['name'],
    data.json()['omginr']['name'],
    data.json()['iostinr']['name'],
    data.json()['dentinr']['name'],
    data.json()['hotinr']['name'],
    data.json()['funinr']['name'],
    data.json()['usdtinr']['name'],
    data.json()['wrxinr']['name'],
    data.json()['maticinr']['name'],
    data.json()['bchinr']['name'],
    data.json()['bnbinr']['name'],
    data.json()['chzinr']['name'],
    data.json()['oneinr']['name'],
    data.json()['yfiinr']['name']
    
]
for i, val in enumerate(cell_value):
    cell_list[i].value = val
    
    wks.update_cells(cell_list)
    time.sleep(10)

# %%
cell_list1= wks.range('B2:B23')
cell_value1 = [
    data.json()['btcinr']['last'],
    data.json()['iostinr']['last'],
    data.json()['xrpinr']['last'],
    data.json()['ethinr']['last'],
    data.json()['zilinr']['last'],
    data.json()['batinr']['last'],
    data.json()['reqinr']['last'],
    data.json()['nulsinr']['last'],
    data.json()['icxinr']['last'],
    data.json()['omginr']['last'],
    data.json()['iostinr']['last'],
    data.json()['dentinr']['last'],
    data.json()['hotinr']['last'],
    data.json()['funinr']['last'],
    data.json()['usdtinr']['last'],
    data.json()['wrxinr']['last'],
    data.json()['maticinr']['last'],
    data.json()['bchinr']['last'],
    data.json()['bnbinr']['last'],
    data.json()['chzinr']['last'],
    data.json()['oneinr']['last'],
    data.json()['yfiinr']['last']
]
for i, val in enumerate(cell_value1):
    cell_list1[i].value = val
    
    wks.update_cells(cell_list1)
    time.sleep(10)
